# %% [markdown]
# https://www.ncss.com/software/ncss/procedures/

# %% [markdown]
# # First Experiments of my PhD

# %% [markdown]
# Datasets used to train the model:
#
# 1. [Wine](https://www.kaggle.com/nareshbhat/wine-quality-binary-classification)
# 2. [Heart](https://www.kaggle.com/ronitf/heart-disease-uci)
# 3. [Diabetes](https://www.kaggle.com/uciml/pima-indians-diabetes-database)
# 4. [Books_LIME](https://www.cs.jhu.edu/~mdredze/datasets/sentiment/index2.html)

# %% [markdown]
# Interpreters used:
#
# 1. [SHAP](https://github.com/slundberg/shap)
# 2. [LIME](https://github.com/marcotcr/lime)
# 3. [DICE](https://github.com/interpretml/DiCE)

# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date
import datetime as dt


diabetes = pd.read_csv('data/datasets_228_482_diabetes.csv', sep = ',')
heart = pd.read_csv('data/datasets_33180_43520_heart.csv', sep = ',')
wine = pd.read_csv('data/datasets_794161_1363233_wine.csv', sep = ',')

print("----------------------------------------------------------------------------------------------")
display(diabetes.head(n = 5))
print("----------------------------------------------------------------------------------------------")
display(heart.head(n = 5))
print("----------------------------------------------------------------------------------------------")
display(wine.head(n = 5))
print("----------------------------------------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------------------------------------
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# ----------------------------------------------------------------------------------------------
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# ...

# %% [markdown]
# The datasets has different names for target variables according to kaggle. In the next cell we will rename de the outcome/quality to 'target' just to keep all of them equal

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date
import datetime as dt


diabetes.rename({'Outcome' : 'target'}, inplace=True, axis=1)

wine['target'] = np.select(
    [
        wine['quality'] == 'bad' , 
        wine['quality'] == 'good'
    ], 
    [
        0, 
        1
    ]
)

# removing the old target
wine = wine[wine.columns.drop(list(wine.filter(regex='quality')))]

wine.to_csv('data/diabetes_limpo.csv', sep = ',')
diabetes.to_csv('data/wine_limpo.csv', sep = ',')

# %% [markdown]
# The number of instances, predictors and data type of each variable:

# %%
print("----------------------------------------------------------------------------------------------")
display("Dataset diabetes has {0} lines and {1} columns".format(diabetes.shape[0], diabetes.shape[1]))
print("----------------------------------------------------------------------------------------------")
display("Dataset heart has {0} lines and {1} columns".format(heart.shape[0], heart.shape[1]))
print("----------------------------------------------------------------------------------------------")
display("Dataset wine has {0} lines and {1} columns".format(wine.shape[0], wine.shape[1]))
print("----------------------------------------------------------------------------------------------")

#Data Types
print("----------------------------------------------------------------------------------------------")
display(diabetes.dtypes)
print("----------------------------------------------------------------------------------------------")
display(heart.dtypes)
print("----------------------------------------------------------------------------------------------")
display(wine.dtypes)
print("----------------------------------------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------------------------------------
# 'Dataset diabetes has 768 lines and 9 columns'
# ----------------------------------------------------------------------------------------------
# 'Dataset heart has 303 lines and 14 columns'
# ----------------------------------------------------------------------------------------------
# 'Dataset wine has 1599 lines and 12 columns'
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# target                        int64
# dtype: object
# ...

# %% [markdown]
# Number of missing values by column:

# %%
#Null
print("----------------------------------------------------------------------------------------------")
display(diabetes.isna().sum())
print("----------------------------------------------------------------------------------------------")
display(heart.isna().sum())
print("----------------------------------------------------------------------------------------------")
display(wine.isna().sum())
print("----------------------------------------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------------------------------------
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# target                      0
# dtype: int64
# ----------------------------------------------------------------------------------------------
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64
# ----------------------------------------------------------------------------------------------
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# ...

# %% [markdown]
# Basic statistics of the datasets:

# %%
#Basic statistics
print("----------------------------------------------------------------------------------------------")
display(diabetes.describe(include = 'all'))
print("----------------------------------------------------------------------------------------------")
display(heart.describe(include = 'all'))
print("----------------------------------------------------------------------------------------------")
display(wine.describe(include = 'all'))
print("----------------------------------------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------------------------------------
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age      target
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# ...
